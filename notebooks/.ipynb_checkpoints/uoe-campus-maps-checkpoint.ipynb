# %%
import folium;
import json;

geoJson=json.load(open('../data/campus-maps.geojson'))

campus_map = folium.Map(location=[55.9450167, -3.1894458],
                    zoom_start=13)

folium.GeoJson(geoJson,
               name='geojson'
              ).add_to(campus_map)

folium.LayerControl().add_to(campus_map)
campus_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
import folium;

campus_map = folium.Map(location=[55.9450167, -3.1894458],
                    zoom_start=13)

campus_map.choropleth(geo_str=open('../data/campus-maps.geojson').read())

campus_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
import folium;
import json;

geoJson=json.load(open('../data/campus-maps.geojson'))

campus_map = folium.Map(location=[55.9450167, -3.1894458],zoom_start=13)

for feature in geoJson['features']:
    long = feature['geometry']['coordinates'][0]
   
    lat = feature['geometry']['coordinates'][1]
   
   
    folium.Marker([long,lat],popup=feature['properties']['name']).add_to(campus_map)
    
campus_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>
